# %%
# E-Commerce Customer Analysis: From Data Engineering to Model Deployment
## Part 1: Data Engineering & Feature Construction

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error, r2_score, classification_report, confusion_matrix
import pickle
import warnings
warnings.filterwarnings('ignore')

# Load the dataset
df = pd.read_csv('marketing_campaign.csv', sep='\t')

# Initial preview
print("First 5 rows of the dataset:")
display(df.head())

# Dataset dimensions
print(f"\nDataset dimensions: {df.shape}")

# Column information
print("\nColumn information:")
print(df.info())

# Numerical vs categorical columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = df.select_dtypes(include=['object']).columns

print(f"\nNumber of numerical columns: {len(numerical_cols)}")
print(f"Number of categorical columns: {len(categorical_cols)}")

# Statistical summaries for numerical columns
print("\nStatistical summaries for numerical columns:")
display(df[numerical_cols].describe().T)

# Unique value counts for categorical columns
print("\nUnique value counts for categorical columns:")
for col in categorical_cols:
    print(f"\n{col}:")
    print(df[col].value_counts())
# Out:
# /tmp/ipython-input-3283461599.py:16: ParserWarning: Skipping line 3: expected 1 fields, saw 2
# Skipping line 5: expected 1 fields, saw 3
# Skipping line 8: expected 1 fields, saw 2
# Skipping line 9: expected 1 fields, saw 3
# Skipping line 10: expected 1 fields, saw 3
# Skipping line 13: expected 1 fields, saw 2
# Skipping line 15: expected 1 fields, saw 2
# Skipping line 17: expected 1 fields, saw 3
# Skipping line 18: expected 1 fields, saw 3
# Skipping line 20: expected 1 fields, saw 2
# Skipping line 21: expected 1 fields, saw 2
# Skipping line 24: expected 1 fields, saw 2
# Skipping line 28: expected 1 fields, saw 2
# Skipping line 32: expected 1 fields, saw 2
# Skipping line 33: expected 1 fields, saw 2
# Skipping line 34: expected 1 fields, saw 2
# Skipping line 35: expected 1 fields, saw 2
# Skipping line 36: expected 1 fields, saw 2
# Skipping line 37: expected 1 fields, saw 2
# Skipping line 41: expected 1 fields, saw 4
# Skipping line 47: expected 1 fields, saw 2
# Skipping line 48: expected 1 fields, saw 2
# Skipping line 54: expected 1 fields, saw 2
# Skipping line 55: expected 1 fields, saw 2
# Skipping line 58: expected 1 fields, saw 3
# Skipping line 60: expected 1 fields, saw 3
# Skipping line 61: expected 1 fields, saw 2
# Skipping line 63: expected 1 fields, saw 2
# Skipping line 64: expected 1 fields, saw 2
# Skipping line 66: expected 1 fields, saw 2
# Skipping line 67: expected 1 fields, saw 2
# Skipping line 74: expected 1 fields, saw 3
# Skipping line 75: expected 1 fields, saw 2
# Skipping line 77: expected 1 fields, saw 3
# Skipping line 78: expected 1 fields, saw 3
# Skipping line 83: expected 1 fields, saw 2
# Skipping line 86: expected 1 fields, saw 2
# Skipping line 88: expected 1 fields, saw 4
# Skipping line 90: expected 1 fields, saw 2
# Skipping line 91: expected 1 fields, saw 2
# Skipping line 93: expected 1 fields, saw 3
# Skipping line 96: expected 1 fields, saw 4
# Skipping line 102: expected 1 fields, saw 2
# Skipping line 104: expected 1 fields, saw 2
# Skipping line 108: expected 1 fields, saw 2
# Skipping line 109: expected 1 fields, saw 4
# Skipping line 114: expected 1 fields, saw 2
# Skipping line 115: expected 1 fields, saw 3
# Skipping line 117: expected 1 fields, saw 4
# Skipping line 118: expected 1 fields, saw 2
# Skipping line 123: expected 1 fields, saw 3
# Skipping line 126: expected 1 fields, saw 2
# Skipping line 132: expected 1 fields, saw 2
# Skipping line 134: expected 1 fields, saw 2
# Skipping line 140: expected 1 fields, saw 2
# Skipping line 143: expected 1 fields, saw 3
# Skipping line 144: expected 1 fields, saw 2
# Skipping line 145: expected 1 fields, saw 2
# Skipping line 146: expected 1 fields, saw 3
# Skipping line 147: expected 1 fields, saw 2
# Skipping line 150: expected 1 fields, saw 4
# Skipping line 152: expected 1 fields, saw 2
# Skipping line 155: expected 1 fields, saw 3
# Skipping line 158: expected 1 fields, saw 2
# Skipping line 161: expected 1 fields, saw 3
# Skipping line 162: expected 1 fields, saw 2
# Skipping line 165: expected 1 fields, saw 2
# Skipping line 168: expected 1 fields, saw 3
# Skipping line 169: expected 1 fields, saw 2
# Skipping line 170: expected 1 fields, saw 3
# Skipping line 175: expected 1 fields, saw 3
# Skipping line 176: expected 1 fields, saw 2
# Skipping line 177: expected 1 fields, saw 3
# Skipping line 181: expected 1 fields, saw 2
# Skipping line 183: expected 1 fields, saw 2
# Skipping line 185: expected 1 fields, saw 2
# Skipping line 186: expected 1 fields, saw 2
# Skipping line 188: expected 1 fields, saw 2
# Skipping line 191: expected 1 fields, saw 5
# Skipping line 193: expected 1 fields, saw 3
# Skipping line 194: expected 1 fields, saw 2
# Skipping line 196: expected 1 fields, saw 2
# Skipping line 198: expected 1 fields, saw 2
# Skipping line 200: expected 1 fields, saw 2
# Skipping line 202: expected 1 fields, saw 2
# Skipping line 204: expected 1 fields, saw 2
# Skipping line 206: expected 1 fields, saw 2
# Skipping line 208: expected 1 fields, saw 2
# Skipping line 210: expected 1 fields, saw 2
# Skipping line 212: expected 1 fields, saw 2
# Skipping line 214: expected 1 fields, saw 2
# Skipping line 216: expected 1 fields, saw 2
# Skipping line 218: expected 1 fields, saw 2
# Skipping line 220: expected 1 fields, saw 2
# Skipping line 222: expected 1 fields, saw 2
# Skipping line 224: expected 1 fields, saw 2
# Skipping line 226: expected 1 fields, saw 2
# Skipping line 228: expected 1 fields, saw 2
# Skipping line 230: expected 1 fields, saw 2
# Skipping line 232: expected 1 fields, saw 2
# Skipping line 234: expected 1 fields, saw 2
# Skipping line 236: expected 1 fields, saw 2
# Skipping line 238: expected 1 fields, saw 2
# Skipping line 240: expected 1 fields, saw 2
# Skipping line 242: expected 1 fields, saw 2
# Skipping line 244: expected 1 fields, saw 2
# Skipping line 246: expected 1 fields, saw 2
# Skipping line 248: expected 1 fields, saw 2
# Skipping line 250: expected 1 fields, saw 2
# Skipping line 252: expected 1 fields, saw 2
# Skipping line 254: expected 1 fields, saw 2
# Skipping line 256: expected 1 fields, saw 2
# Skipping line 258: expected 1 fields, saw 2
# Skipping line 260: expected 1 fields, saw 2
# Skipping line 262: expected 1 fields, saw 2
# Skipping line 264: expected 1 fields, saw 2
# Skipping line 266: expected 1 fields, saw 2
# Skipping line 268: expected 1 fields, saw 2
# Skipping line 270: expected 1 fields, saw 2
# Skipping line 272: expected 1 fields, saw 2
# Skipping line 274: expected 1 fields, saw 2
# Skipping line 276: expected 1 fields, saw 2
# Skipping line 278: expected 1 fields, saw 2
# Skipping line 280: expected 1 fields, saw 2
# Skipping line 282: expected 1 fields, saw 2
# Skipping line 284: expected 1 fields, saw 2
# Skipping line 286: expected 1 fields, saw 2
# Skipping line 288: expected 1 fields, saw 2
# Skipping line 290: expected 1 fields, saw 2
# Skipping line 292: expected 1 fields, saw 2
# Skipping line 294: expected 1 fields, saw 2
# Skipping line 296: expected 1 fields, saw 2
# Skipping line 298: expected 1 fields, saw 2
# Skipping line 300: expected 1 fields, saw 2
# Skipping line 302: expected 1 fields, saw 2
# Skipping line 304: expected 1 fields, saw 2
# Skipping line 306: expected 1 fields, saw 2
# Skipping line 308: expected 1 fields, saw 2
# Skipping line 310: expected 1 fields, saw 2
# Skipping line 312: expected 1 fields, saw 2
# Skipping line 314: expected 1 fields, saw 2
# Skipping line 316: expected 1 fields, saw 2
# Skipping line 318: expected 1 fields, saw 2
# Skipping line 320: expected 1 fields, saw 2
# Skipping line 322: expected 1 fields, saw 2
# Skipping line 324: expected 1 fields, saw 2
# Skipping line 326: expected 1 fields, saw 2
# Skipping line 328: expected 1 fields, saw 2
# Skipping line 330: expected 1 fields, saw 2
# Skipping line 332: expected 1 fields, saw 2
# Skipping line 334: expected 1 fields, saw 2
# Skipping line 336: expected 1 fields, saw 2
# Skipping line 338: expected 1 fields, saw 2
# Skipping line 340: expected 1 fields, saw 2
# Skipping line 342: expected 1 fields, saw 2
# Skipping line 344: expected 1 fields, saw 2
# Skipping line 346: expected 1 fields, saw 2
# Skipping line 348: expected 1 fields, saw 2
# Skipping line 350: expected 1 fields, saw 2
# Skipping line 352: expected 1 fields, saw 2
# Skipping line 354: expected 1 fields, saw 2
# Skipping line 356: expected 1 fields, saw 2
# Skipping line 358: expected 1 fields, saw 2
# Skipping line 360: expected 1 fields, saw 2
# Skipping line 362: expected 1 fields, saw 2
# Skipping line 364: expected 1 fields, saw 2
# Skipping line 366: expected 1 fields, saw 2
# Skipping line 368: expected 1 fields, saw 2
# Skipping line 370: expected 1 fields, saw 2
# Skipping line 372: expected 1 fields, saw 2
# Skipping line 374: expected 1 fields, saw 2
# Skipping line 376: expected 1 fields, saw 2
# Skipping line 378: expected 1 fields, saw 2
# Skipping line 380: expected 1 fields, saw 2
# Skipping line 382: expected 1 fields, saw 2
# Skipping line 384: expected 1 fields, saw 2
# Skipping line 386: expected 1 fields, saw 2
# Skipping line 388: expected 1 fields, saw 2
# Skipping line 390: expected 1 fields, saw 2
# Skipping line 392: expected 1 fields, saw 2
# Skipping line 394: expected 1 fields, saw 2
# Skipping line 396: expected 1 fields, saw 2
# Skipping line 398: expected 1 fields, saw 2
# Skipping line 400: expected 1 fields, saw 2
# Skipping line 402: expected 1 fields, saw 2
# Skipping line 404: expected 1 fields, saw 2
# Skipping line 406: expected 1 fields, saw 2
# Skipping line 408: expected 1 fields, saw 2
# Skipping line 410: expected 1 fields, saw 2
# Skipping line 412: expected 1 fields, saw 2
# Skipping line 414: expected 1 fields, saw 2
# Skipping line 416: expected 1 fields, saw 2
# Skipping line 418: expected 1 fields, saw 2
# Skipping line 420: expected 1 fields, saw 2
# Skipping line 422: expected 1 fields, saw 2
# Skipping line 424: expected 1 fields, saw 2
# Skipping line 426: expected 1 fields, saw 2
# Skipping line 428: expected 1 fields, saw 2
# Skipping line 430: expected 1 fields, saw 2
# Skipping line 432: expected 1 fields, saw 2
# Skipping line 434: expected 1 fields, saw 2
# Skipping line 436: expected 1 fields, saw 2
# Skipping line 438: expected 1 fields, saw 2
# Skipping line 440: expected 1 fields, saw 2
# Skipping line 442: expected 1 fields, saw 2
# Skipping line 444: expected 1 fields, saw 2
# Skipping line 446: expected 1 fields, saw 2
# Skipping line 448: expected 1 fields, saw 2
# Skipping line 450: expected 1 fields, saw 2
# Skipping line 452: expected 1 fields, saw 2
# Skipping line 454: expected 1 fields, saw 2
# Skipping line 456: expected 1 fields, saw 2
# Skipping line 458: expected 1 fields, saw 2
# Skipping line 460: expected 1 fields, saw 2
# Skipping line 462: expected 1 fields, saw 2
# Skipping line 464: expected 1 fields, saw 2
# Skipping line 466: expected 1 fields, saw 2
# Skipping line 468: expected 1 fields, saw 2
# Skipping line 470: expected 1 fields, saw 2
# Skipping line 472: expected 1 fields, saw 2
# Skipping line 474: expected 1 fields, saw 2
# Skipping line 476: expected 1 fields, saw 2
# Skipping line 478: expected 1 fields, saw 2
# Skipping line 480: expected 1 fields, saw 2
# Skipping line 482: expected 1 fields, saw 2
# Skipping line 484: expected 1 fields, saw 2
# Skipping line 486: expected 1 fields, saw 2
# Skipping line 488: expected 1 fields, saw 2
# Skipping line 490: expected 1 fields, saw 2
# Skipping line 492: expected 1 fields, saw 2
# Skipping line 494: expected 1 fields, saw 2
# Skipping line 496: expected 1 fields, saw 2
# Skipping line 498: expected 1 fields, saw 2
# Skipping line 500: expected 1 fields, saw 2
# Skipping line 502: expected 1 fields, saw 2
# Skipping line 504: expected 1 fields, saw 2
# Skipping line 506: expected 1 fields, saw 2
# Skipping line 508: expected 1 fields, saw 2
# Skipping line 510: expected 1 fields, saw 2
# Skipping line 512: expected 1 fields, saw 2
# Skipping line 514: expected 1 fields, saw 2
# Skipping line 516: expected 1 fields, saw 2
# Skipping line 518: expected 1 fields, saw 2
# Skipping line 520: expected 1 fields, saw 2
# Skipping line 522: expected 1 fields, saw 2
# Skipping line 524: expected 1 fields, saw 2
# Skipping line 526: expected 1 fields, saw 2
# Skipping line 528: expected 1 fields, saw 2
# Skipping line 530: expected 1 fields, saw 2
# Skipping line 532: expected 1 fields, saw 2
# Skipping line 534: expected 1 fields, saw 2
# Skipping line 536: expected 1 fields, saw 2
# Skipping line 538: expected 1 fields, saw 2
# Skipping line 540: expected 1 fields, saw 2
# Skipping line 542: expected 1 fields, saw 2
# Skipping line 544: expected 1 fields, saw 2
# Skipping line 546: expected 1 fields, saw 2
# Skipping line 548: expected 1 fields, saw 2
# Skipping line 550: expected 1 fields, saw 2
# Skipping line 552: expected 1 fields, saw 2
# Skipping line 554: expected 1 fields, saw 2
# Skipping line 556: expected 1 fields, saw 2
# Skipping line 558: expected 1 fields, saw 2
# Skipping line 560: expected 1 fields, saw 2
# Skipping line 562: expected 1 fields, saw 2
# Skipping line 564: expected 1 fields, saw 2
# Skipping line 566: expected 1 fields, saw 2
# Skipping line 568: expected 1 fields, saw 2
# Skipping line 570: expected 1 fields, saw 2
# Skipping line 572: expected 1 fields, saw 2
# Skipping line 574: expected 1 fields, saw 2
# Skipping line 576: expected 1 fields, saw 2
# Skipping line 578: expected 1 fields, saw 2
# Skipping line 580: expected 1 fields, saw 2
# Skipping line 582: expected 1 fields, saw 2
# Skipping line 584: expected 1 fields, saw 2
# Skipping line 586: expected 1 fields, saw 2
# Skipping line 588: expected 1 fields, saw 2
# Skipping line 590: expected 1 fields, saw 2
# Skipping line 592: expected 1 fields, saw 2
# Skipping line 594: expected 1 fields, saw 2
# Skipping line 596: expected 1 fields, saw 2
# Skipping line 598: expected 1 fields, saw 2
# Skipping line 600: expected 1 fields, saw 2
# Skipping line 602: expected 1 fields, saw 2
# Skipping line 604: expected 1 fields, saw 2
# Skipping line 606: expected 1 fields, saw 2
# Skipping line 608: expected 1 fields, saw 2
# Skipping line 610: expected 1 fields, saw 2
# Skipping line 612: expected 1 fields, saw 2
# Skipping line 614: expected 1 fields, saw 2
# Skipping line 616: expected 1 fields, saw 2
# Skipping line 618: expected 1 fields, saw 2
# Skipping line 620: expected 1 fields, saw 2
# Skipping line 622: expected 1 fields, saw 2
# Skipping line 624: expected 1 fields, saw 2
# Skipping line 626: expected 1 fields, saw 2
# Skipping line 628: expected 1 fields, saw 2
# Skipping line 630: expected 1 fields, saw 2
# Skipping line 632: expected 1 fields, saw 2
# Skipping line 634: expected 1 fields, saw 2
# Skipping line 636: expected 1 fields, saw 2
# Skipping line 638: expected 1 fields, saw 2
# Skipping line 640: expected 1 fields, saw 2
# Skipping line 642: expected 1 fields, saw 2
# Skipping line 644: expected 1 fields, saw 2
# Skipping line 646: expected 1 fields, saw 2
# Skipping line 648: expected 1 fields, saw 2
# Skipping line 650: expected 1 fields, saw 2
# Skipping line 652: expected 1 fields, saw 2
# Skipping line 654: expected 1 fields, saw 2
# Skipping line 656: expected 1 fields, saw 2
# Skipping line 658: expected 1 fields, saw 2
# Skipping line 660: expected 1 fields, saw 2
# Skipping line 662: expected 1 fields, saw 2
# Skipping line 664: expected 1 fields, saw 2
# Skipping line 666: expected 1 fields, saw 2
# Skipping line 668: expected 1 fields, saw 2
# Skipping line 670: expected 1 fields, saw 2
# Skipping line 672: expected 1 fields, saw 2
# Skipping line 674: expected 1 fields, saw 2
# Skipping line 676: expected 1 fields, saw 2
# Skipping line 678: expected 1 fields, saw 2
# Skipping line 680: expected 1 fields, saw 2
# Skipping line 682: expected 1 fields, saw 2
# Skipping line 684: expected 1 fields, saw 2
# Skipping line 686: expected 1 fields, saw 2
# Skipping line 688: expected 1 fields, saw 2
# Skipping line 690: expected 1 fields, saw 2
# Skipping line 692: expected 1 fields, saw 2
# Skipping line 694: expected 1 fields, saw 2
# Skipping line 696: expected 1 fields, saw 2
# Skipping line 698: expected 1 fields, saw 2
# Skipping line 700: expected 1 fields, saw 2
# Skipping line 702: expected 1 fields, saw 2
# Skipping line 704: expected 1 fields, saw 2
# Skipping line 706: expected 1 fields, saw 2
# Skipping line 708: expected 1 fields, saw 2
# Skipping line 710: expected 1 fields, saw 2
# Skipping line 712: expected 1 fields, saw 2
# Skipping line 714: expected 1 fields, saw 2
# Skipping line 716: expected 1 fields, saw 2
# Skipping line 718: expected 1 fields, saw 2
# Skipping line 720: expected 1 fields, saw 2
# Skipping line 722: expected 1 fields, saw 2
# Skipping line 724: expected 1 fields, saw 2
# Skipping line 726: expected 1 fields, saw 2
# Skipping line 728: expected 1 fields, saw 2
# Skipping line 730: expected 1 fields, saw 2
# Skipping line 732: expected 1 fields, saw 2
# Skipping line 734: expected 1 fields, saw 2
# Skipping line 736: expected 1 fields, saw 2
# Skipping line 738: expected 1 fields, saw 2
# Skipping line 740: expected 1 fields, saw 2
# Skipping line 742: expected 1 fields, saw 2
# Skipping line 744: expected 1 fields, saw 2
# Skipping line 746: expected 1 fields, saw 2
# Skipping line 748: expected 1 fields, saw 2
# Skipping line 750: expected 1 fields, saw 2
# Skipping line 752: expected 1 fields, saw 2
# Skipping line 754: expected 1 fields, saw 2
# Skipping line 756: expected 1 fields, saw 2
# Skipping line 758: expected 1 fields, saw 2
# Skipping line 760: expected 1 fields, saw 2
# Skipping line 762: expected 1 fields, saw 2
# Skipping line 764: expected 1 fields, saw 2
# Skipping line 766: expected 1 fields, saw 2
# Skipping line 768: expected 1 fields, saw 2
# Skipping line 770: expected 1 fields, saw 2
# Skipping line 772: expected 1 fields, saw 2
# Skipping line 774: expected 1 fields, saw 2
# Skipping line 776: expected 1 fields, saw 2
# Skipping line 778: expected 1 fields, saw 2
# Skipping line 780: expected 1 fields, saw 2
# Skipping line 782: expected 1 fields, saw 2
# Skipping line 784: expected 1 fields, saw 2
# Skipping line 786: expected 1 fields, saw 2
# Skipping line 788: expected 1 fields, saw 2
# Skipping line 790: expected 1 fields, saw 2
# Skipping line 792: expected 1 fields, saw 2
# Skipping line 794: expected 1 fields, saw 2
# Skipping line 796: expected 1 fields, saw 2
# Skipping line 798: expected 1 fields, saw 2
# Skipping line 800: expected 1 fields, saw 2
# Skipping line 802: expected 1 fields, saw 2
# Skipping line 804: expected 1 fields, saw 2
# Skipping line 806: expected 1 fields, saw 2
# Skipping line 808: expected 1 fields, saw 2
# Skipping line 810: expected 1 fields, saw 2
# Skipping line 812: expected 1 fields, saw 2
# Skipping line 814: expected 1 fields, saw 2
# Skipping line 816: expected 1 fields, saw 2
# Skipping line 818: expected 1 fields, saw 2
# Skipping line 820: expected 1 fields, saw 2
# Skipping line 822: expected 1 fields, saw 2
# Skipping line 824: expected 1 fields, saw 2
# Skipping line 826: expected 1 fields, saw 2
# Skipping line 828: expected 1 fields, saw 2
# Skipping line 830: expected 1 fields, saw 2
# Skipping line 832: expected 1 fields, saw 2
# Skipping line 834: expected 1 fields, saw 2
# Skipping line 836: expected 1 fields, saw 2
# Skipping line 838: expected 1 fields, saw 2
# Skipping line 840: expected 1 fields, saw 2
# Skipping line 842: expected 1 fields, saw 2
# Skipping line 844: expected 1 fields, saw 2
# Skipping line 846: expected 1 fields, saw 2
# Skipping line 848: expected 1 fields, saw 2
# Skipping line 850: expected 1 fields, saw 2
# Skipping line 852: expected 1 fields, saw 2
# Skipping line 854: expected 1 fields, saw 2
# Skipping line 856: expected 1 fields, saw 2
# Skipping line 858: expected 1 fields, saw 2
# Skipping line 860: expected 1 fields, saw 2
# Skipping line 862: expected 1 fields, saw 2
# Skipping line 864: expected 1 fields, saw 2
# Skipping line 866: expected 1 fields, saw 2
# Skipping line 868: expected 1 fields, saw 2
# Skipping line 870: expected 1 fields, saw 2
# Skipping line 872: expected 1 fields, saw 2
# Skipping line 874: expected 1 fields, saw 2
# Skipping line 876: expected 1 fields, saw 2
# Skipping line 878: expected 1 fields, saw 2
# Skipping line 880: expected 1 fields, saw 2
# Skipping line 882: expected 1 fields, saw 2
# Skipping line 884: expected 1 fields, saw 2
# Skipping line 886: expected 1 fields, saw 2
# Skipping line 888: expected 1 fields, saw 2
# Skipping line 890: expected 1 fields, saw 2
# Skipping line 892: expected 1 fields, saw 2
# Skipping line 894: expected 1 fields, saw 2
# Skipping line 896: expected 1 fields, saw 2
# Skipping line 898: expected 1 fields, saw 2
# Skipping line 900: expected 1 fields, saw 2
# Skipping line 902: expected 1 fields, saw 2
# Skipping line 904: expected 1 fields, saw 2
# Skipping line 906: expected 1 fields, saw 2
# Skipping line 908: expected 1 fields, saw 2
# Skipping line 910: expected 1 fields, saw 2
#
#   df = pd.read_csv(url, encoding='utf-8', on_bad_lines='warn')
# UTF-8 failed: Error tokenizing data. C error: Buffer overflow caught - possible malformed input file.
# /tmp/ipython-input-3283461599.py:22: ParserWarning: Skipping line 3: expected 1 fields, saw 2
# Skipping line 5: expected 1 fields, saw 3
# Skipping line 8: expected 1 fields, saw 2
# Skipping line 9: expected 1 fields, saw 3
# Skipping line 10: expected 1 fields, saw 3
# Skipping line 13: expected 1 fields, saw 2
# Skipping line 15: expected 1 fields, saw 2
# Skipping line 17: expected 1 fields, saw 3
# Skipping line 18: expected 1 fields, saw 3
# Skipping line 20: expected 1 fields, saw 2
# Skipping line 21: expected 1 fields, saw 2
# Skipping line 24: expected 1 fields, saw 2
# Skipping line 28: expected 1 fields, saw 2
# Skipping line 32: expected 1 fields, saw 2
# Skipping line 33: expected 1 fields, saw 2
# Skipping line 34: expected 1 fields, saw 2
# Skipping line 35: expected 1 fields, saw 2
# Skipping line 36: expected 1 fields, saw 2
# Skipping line 37: expected 1 fields, saw 2
# Skipping line 41: expected 1 fields, saw 4
# Skipping line 47: expected 1 fields, saw 2
# Skipping line 48: expected 1 fields, saw 2
# Skipping line 54: expected 1 fields, saw 2
# Skipping line 55: expected 1 fields, saw 2
# Skipping line 58: expected 1 fields, saw 3
# Skipping line 60: expected 1 fields, saw 3
# Skipping line 61: expected 1 fields, saw 2
# Skipping line 63: expected 1 fields, saw 2
# Skipping line 64: expected 1 fields, saw 2
# Skipping line 66: expected 1 fields, saw 2
# Skipping line 67: expected 1 fields, saw 2
# Skipping line 74: expected 1 fields, saw 3
# Skipping line 75: expected 1 fields, saw 2
# Skipping line 77: expected 1 fields, saw 3
# Skipping line 78: expected 1 fields, saw 3
# Skipping line 83: expected 1 fields, saw 2
# Skipping line 86: expected 1 fields, saw 2
# Skipping line 88: expected 1 fields, saw 4
# Skipping line 90: expected 1 fields, saw 2
# Skipping line 91: expected 1 fields, saw 2
# Skipping line 93: expected 1 fields, saw 3
# Skipping line 96: expected 1 fields, saw 4
# Skipping line 102: expected 1 fields, saw 2
# Skipping line 104: expected 1 fields, saw 2
# Skipping line 108: expected 1 fields, saw 2
# Skipping line 109: expected 1 fields, saw 4
# Skipping line 114: expected 1 fields, saw 2
# Skipping line 115: expected 1 fields, saw 3
# Skipping line 117: expected 1 fields, saw 4
# Skipping line 118: expected 1 fields, saw 2
# Skipping line 123: expected 1 fields, saw 3
# Skipping line 126: expected 1 fields, saw 2
# Skipping line 132: expected 1 fields, saw 2
# Skipping line 134: expected 1 fields, saw 2
# Skipping line 140: expected 1 fields, saw 2
# Skipping line 143: expected 1 fields, saw 3
# Skipping line 144: expected 1 fields, saw 2
# Skipping line 145: expected 1 fields, saw 2
# Skipping line 146: expected 1 fields, saw 3
# Skipping line 147: expected 1 fields, saw 2
# Skipping line 150: expected 1 fields, saw 4
# Skipping line 152: expected 1 fields, saw 2
# Skipping line 155: expected 1 fields, saw 3
# Skipping line 158: expected 1 fields, saw 2
# Skipping line 161: expected 1 fields, saw 3
# Skipping line 162: expected 1 fields, saw 2
# Skipping line 165: expected 1 fields, saw 2
# Skipping line 168: expected 1 fields, saw 3
# Skipping line 169: expected 1 fields, saw 2
# Skipping line 170: expected 1 fields, saw 3
# Skipping line 175: expected 1 fields, saw 3
# Skipping line 176: expected 1 fields, saw 2
# Skipping line 177: expected 1 fields, saw 3
# Skipping line 181: expected 1 fields, saw 2
# Skipping line 183: expected 1 fields, saw 2
# Skipping line 185: expected 1 fields, saw 2
# Skipping line 186: expected 1 fields, saw 2
# Skipping line 188: expected 1 fields, saw 2
# Skipping line 191: expected 1 fields, saw 5
# Skipping line 193: expected 1 fields, saw 3
# Skipping line 194: expected 1 fields, saw 2
# Skipping line 196: expected 1 fields, saw 2
# Skipping line 198: expected 1 fields, saw 2
# Skipping line 200: expected 1 fields, saw 2
# Skipping line 202: expected 1 fields, saw 2
# Skipping line 204: expected 1 fields, saw 2
# Skipping line 206: expected 1 fields, saw 2
# Skipping line 208: expected 1 fields, saw 2
# Skipping line 210: expected 1 fields, saw 2
# Skipping line 212: expected 1 fields, saw 2
# Skipping line 214: expected 1 fields, saw 2
# Skipping line 216: expected 1 fields, saw 2
# Skipping line 218: expected 1 fields, saw 2
# Skipping line 220: expected 1 fields, saw 2
# Skipping line 222: expected 1 fields, saw 2
# Skipping line 224: expected 1 fields, saw 2
# Skipping line 226: expected 1 fields, saw 2
# Skipping line 228: expected 1 fields, saw 2
# Skipping line 230: expected 1 fields, saw 2
# Skipping line 232: expected 1 fields, saw 2
# Skipping line 234: expected 1 fields, saw 2
# Skipping line 236: expected 1 fields, saw 2
# Skipping line 238: expected 1 fields, saw 2
# Skipping line 240: expected 1 fields, saw 2
# Skipping line 242: expected 1 fields, saw 2
# Skipping line 244: expected 1 fields, saw 2
# Skipping line 246: expected 1 fields, saw 2
# Skipping line 248: expected 1 fields, saw 2
# Skipping line 250: expected 1 fields, saw 2
# Skipping line 252: expected 1 fields, saw 2
# Skipping line 254: expected 1 fields, saw 2
# Skipping line 256: expected 1 fields, saw 2
# Skipping line 258: expected 1 fields, saw 2
# Skipping line 260: expected 1 fields, saw 2
# Skipping line 262: expected 1 fields, saw 2
# Skipping line 264: expected 1 fields, saw 2
# Skipping line 266: expected 1 fields, saw 2
# Skipping line 268: expected 1 fields, saw 2
# Skipping line 270: expected 1 fields, saw 2
# Skipping line 272: expected 1 fields, saw 2
# Skipping line 274: expected 1 fields, saw 2
# Skipping line 276: expected 1 fields, saw 2
# Skipping line 278: expected 1 fields, saw 2
# Skipping line 280: expected 1 fields, saw 2
# Skipping line 282: expected 1 fields, saw 2
# Skipping line 284: expected 1 fields, saw 2
# Skipping line 286: expected 1 fields, saw 2
# Skipping line 288: expected 1 fields, saw 2
# Skipping line 290: expected 1 fields, saw 2
# Skipping line 292: expected 1 fields, saw 2
# Skipping line 294: expected 1 fields, saw 2
# Skipping line 296: expected 1 fields, saw 2
# Skipping line 298: expected 1 fields, saw 2
# Skipping line 300: expected 1 fields, saw 2
# Skipping line 302: expected 1 fields, saw 2
# Skipping line 304: expected 1 fields, saw 2
# Skipping line 306: expected 1 fields, saw 2
# Skipping line 308: expected 1 fields, saw 2
# Skipping line 310: expected 1 fields, saw 2
# Skipping line 312: expected 1 fields, saw 2
# Skipping line 314: expected 1 fields, saw 2
# Skipping line 316: expected 1 fields, saw 2
# Skipping line 318: expected 1 fields, saw 2
# Skipping line 320: expected 1 fields, saw 2
# Skipping line 322: expected 1 fields, saw 2
# Skipping line 324: expected 1 fields, saw 2
# Skipping line 326: expected 1 fields, saw 2
# Skipping line 328: expected 1 fields, saw 2
# Skipping line 330: expected 1 fields, saw 2
# Skipping line 332: expected 1 fields, saw 2
# Skipping line 334: expected 1 fields, saw 2
# Skipping line 336: expected 1 fields, saw 2
# Skipping line 338: expected 1 fields, saw 2
# Skipping line 340: expected 1 fields, saw 2
# Skipping line 342: expected 1 fields, saw 2
# Skipping line 344: expected 1 fields, saw 2
# Skipping line 346: expected 1 fields, saw 2
# Skipping line 348: expected 1 fields, saw 2
# Skipping line 350: expected 1 fields, saw 2
# Skipping line 352: expected 1 fields, saw 2
# Skipping line 354: expected 1 fields, saw 2
# Skipping line 356: expected 1 fields, saw 2
# Skipping line 358: expected 1 fields, saw 2
# Skipping line 360: expected 1 fields, saw 2
# Skipping line 362: expected 1 fields, saw 2
# Skipping line 364: expected 1 fields, saw 2
# Skipping line 366: expected 1 fields, saw 2
# Skipping line 368: expected 1 fields, saw 2
# Skipping line 370: expected 1 fields, saw 2
# Skipping line 372: expected 1 fields, saw 2
# Skipping line 374: expected 1 fields, saw 2
# Skipping line 376: expected 1 fields, saw 2
# Skipping line 378: expected 1 fields, saw 2
# Skipping line 380: expected 1 fields, saw 2
# Skipping line 382: expected 1 fields, saw 2
# Skipping line 384: expected 1 fields, saw 2
# Skipping line 386: expected 1 fields, saw 2
# Skipping line 388: expected 1 fields, saw 2
# Skipping line 390: expected 1 fields, saw 2
# Skipping line 392: expected 1 fields, saw 2
# Skipping line 394: expected 1 fields, saw 2
# Skipping line 396: expected 1 fields, saw 2
# Skipping line 398: expected 1 fields, saw 2
# Skipping line 400: expected 1 fields, saw 2
# Skipping line 402: expected 1 fields, saw 2
# Skipping line 404: expected 1 fields, saw 2
# Skipping line 406: expected 1 fields, saw 2
# Skipping line 408: expected 1 fields, saw 2
# Skipping line 410: expected 1 fields, saw 2
# Skipping line 412: expected 1 fields, saw 2
# Skipping line 414: expected 1 fields, saw 2
# Skipping line 416: expected 1 fields, saw 2
# Skipping line 418: expected 1 fields, saw 2
# Skipping line 420: expected 1 fields, saw 2
# Skipping line 422: expected 1 fields, saw 2
# Skipping line 424: expected 1 fields, saw 2
# Skipping line 426: expected 1 fields, saw 2
# Skipping line 428: expected 1 fields, saw 2
# Skipping line 430: expected 1 fields, saw 2
# Skipping line 432: expected 1 fields, saw 2
# Skipping line 434: expected 1 fields, saw 2
# Skipping line 436: expected 1 fields, saw 2
# Skipping line 438: expected 1 fields, saw 2
# Skipping line 440: expected 1 fields, saw 2
# Skipping line 442: expected 1 fields, saw 2
# Skipping line 444: expected 1 fields, saw 2
# Skipping line 446: expected 1 fields, saw 2
# Skipping line 448: expected 1 fields, saw 2
# Skipping line 450: expected 1 fields, saw 2
# Skipping line 452: expected 1 fields, saw 2
# Skipping line 454: expected 1 fields, saw 2
# Skipping line 456: expected 1 fields, saw 2
# Skipping line 458: expected 1 fields, saw 2
# Skipping line 460: expected 1 fields, saw 2
# Skipping line 462: expected 1 fields, saw 2
# Skipping line 464: expected 1 fields, saw 2
# Skipping line 466: expected 1 fields, saw 2
# Skipping line 468: expected 1 fields, saw 2
# Skipping line 470: expected 1 fields, saw 2
# Skipping line 472: expected 1 fields, saw 2
# Skipping line 474: expected 1 fields, saw 2
# Skipping line 476: expected 1 fields, saw 2
# Skipping line 478: expected 1 fields, saw 2
# Skipping line 480: expected 1 fields, saw 2
# Skipping line 482: expected 1 fields, saw 2
# Skipping line 484: expected 1 fields, saw 2
# Skipping line 486: expected 1 fields, saw 2
# Skipping line 488: expected 1 fields, saw 2
# Skipping line 490: expected 1 fields, saw 2
# Skipping line 492: expected 1 fields, saw 2
# Skipping line 494: expected 1 fields, saw 2
# Skipping line 496: expected 1 fields, saw 2
# Skipping line 498: expected 1 fields, saw 2
# Skipping line 500: expected 1 fields, saw 2
# Skipping line 502: expected 1 fields, saw 2
# Skipping line 504: expected 1 fields, saw 2
# Skipping line 506: expected 1 fields, saw 2
# Skipping line 508: expected 1 fields, saw 2
# Skipping line 510: expected 1 fields, saw 2
# Skipping line 512: expected 1 fields, saw 2
# Skipping line 514: expected 1 fields, saw 2
# Skipping line 516: expected 1 fields, saw 2
# Skipping line 518: expected 1 fields, saw 2
# Skipping line 520: expected 1 fields, saw 2
# Skipping line 522: expected 1 fields, saw 2
# Skipping line 524: expected 1 fields, saw 2
# Skipping line 526: expected 1 fields, saw 2
# Skipping line 528: expected 1 fields, saw 2
# Skipping line 530: expected 1 fields, saw 2
# Skipping line 532: expected 1 fields, saw 2
# Skipping line 534: expected 1 fields, saw 2
# Skipping line 536: expected 1 fields, saw 2
# Skipping line 538: expected 1 fields, saw 2
# Skipping line 540: expected 1 fields, saw 2
# Skipping line 542: expected 1 fields, saw 2
# Skipping line 544: expected 1 fields, saw 2
# Skipping line 546: expected 1 fields, saw 2
# Skipping line 548: expected 1 fields, saw 2
# Skipping line 550: expected 1 fields, saw 2
# Skipping line 552: expected 1 fields, saw 2
# Skipping line 554: expected 1 fields, saw 2
# Skipping line 556: expected 1 fields, saw 2
# Skipping line 558: expected 1 fields, saw 2
# Skipping line 560: expected 1 fields, saw 2
# Skipping line 562: expected 1 fields, saw 2
# Skipping line 564: expected 1 fields, saw 2
# Skipping line 566: expected 1 fields, saw 2
# Skipping line 568: expected 1 fields, saw 2
# Skipping line 570: expected 1 fields, saw 2
# Skipping line 572: expected 1 fields, saw 2
# Skipping line 574: expected 1 fields, saw 2
# Skipping line 576: expected 1 fields, saw 2
# Skipping line 578: expected 1 fields, saw 2
# Skipping line 580: expected 1 fields, saw 2
# Skipping line 582: expected 1 fields, saw 2
# Skipping line 584: expected 1 fields, saw 2
# Skipping line 586: expected 1 fields, saw 2
# Skipping line 588: expected 1 fields, saw 2
# Skipping line 590: expected 1 fields, saw 2
# Skipping line 592: expected 1 fields, saw 2
# Skipping line 594: expected 1 fields, saw 2
# Skipping line 596: expected 1 fields, saw 2
# Skipping line 598: expected 1 fields, saw 2
# Skipping line 600: expected 1 fields, saw 2
# Skipping line 602: expected 1 fields, saw 2
# Skipping line 604: expected 1 fields, saw 2
# Skipping line 606: expected 1 fields, saw 2
# Skipping line 608: expected 1 fields, saw 2
# Skipping line 610: expected 1 fields, saw 2
# Skipping line 612: expected 1 fields, saw 2
# Skipping line 614: expected 1 fields, saw 2
# Skipping line 616: expected 1 fields, saw 2
# Skipping line 618: expected 1 fields, saw 2
# Skipping line 620: expected 1 fields, saw 2
# Skipping line 622: expected 1 fields, saw 2
# Skipping line 624: expected 1 fields, saw 2
# Skipping line 626: expected 1 fields, saw 2
# Skipping line 628: expected 1 fields, saw 2
# Skipping line 630: expected 1 fields, saw 2
# Skipping line 632: expected 1 fields, saw 2
# Skipping line 634: expected 1 fields, saw 2
# Skipping line 636: expected 1 fields, saw 2
# Skipping line 638: expected 1 fields, saw 2
# Skipping line 640: expected 1 fields, saw 2
# Skipping line 642: expected 1 fields, saw 2
# Skipping line 644: expected 1 fields, saw 2
# Skipping line 646: expected 1 fields, saw 2
# Skipping line 648: expected 1 fields, saw 2
# Skipping line 650: expected 1 fields, saw 2
# Skipping line 652: expected 1 fields, saw 2
# Skipping line 654: expected 1 fields, saw 2
# Skipping line 656: expected 1 fields, saw 2
# Skipping line 658: expected 1 fields, saw 2
# Skipping line 660: expected 1 fields, saw 2
# Skipping line 662: expected 1 fields, saw 2
# Skipping line 664: expected 1 fields, saw 2
# Skipping line 666: expected 1 fields, saw 2
# Skipping line 668: expected 1 fields, saw 2
# Skipping line 670: expected 1 fields, saw 2
# Skipping line 672: expected 1 fields, saw 2
# Skipping line 674: expected 1 fields, saw 2
# Skipping line 676: expected 1 fields, saw 2
# Skipping line 678: expected 1 fields, saw 2
# Skipping line 680: expected 1 fields, saw 2
# Skipping line 682: expected 1 fields, saw 2
# Skipping line 684: expected 1 fields, saw 2
# Skipping line 686: expected 1 fields, saw 2
# Skipping line 688: expected 1 fields, saw 2
# Skipping line 690: expected 1 fields, saw 2
# Skipping line 692: expected 1 fields, saw 2
# Skipping line 694: expected 1 fields, saw 2
# Skipping line 696: expected 1 fields, saw 2
# Skipping line 698: expected 1 fields, saw 2
# Skipping line 700: expected 1 fields, saw 2
# Skipping line 702: expected 1 fields, saw 2
# Skipping line 704: expected 1 fields, saw 2
# Skipping line 706: expected 1 fields, saw 2
# Skipping line 708: expected 1 fields, saw 2
# Skipping line 710: expected 1 fields, saw 2
# Skipping line 712: expected 1 fields, saw 2
# Skipping line 714: expected 1 fields, saw 2
# Skipping line 716: expected 1 fields, saw 2
# Skipping line 718: expected 1 fields, saw 2
# Skipping line 720: expected 1 fields, saw 2
# Skipping line 722: expected 1 fields, saw 2
# Skipping line 724: expected 1 fields, saw 2
# Skipping line 726: expected 1 fields, saw 2
# Skipping line 728: expected 1 fields, saw 2
# Skipping line 730: expected 1 fields, saw 2
# Skipping line 732: expected 1 fields, saw 2
# Skipping line 734: expected 1 fields, saw 2
# Skipping line 736: expected 1 fields, saw 2
# Skipping line 738: expected 1 fields, saw 2
# Skipping line 740: expected 1 fields, saw 2
# Skipping line 742: expected 1 fields, saw 2
# Skipping line 744: expected 1 fields, saw 2
# Skipping line 746: expected 1 fields, saw 2
# Skipping line 748: expected 1 fields, saw 2
# Skipping line 750: expected 1 fields, saw 2
# Skipping line 752: expected 1 fields, saw 2
# Skipping line 754: expected 1 fields, saw 2
# Skipping line 756: expected 1 fields, saw 2
# Skipping line 758: expected 1 fields, saw 2
# Skipping line 760: expected 1 fields, saw 2
# Skipping line 762: expected 1 fields, saw 2
# Skipping line 764: expected 1 fields, saw 2
# Skipping line 766: expected 1 fields, saw 2
# Skipping line 768: expected 1 fields, saw 2
# Skipping line 770: expected 1 fields, saw 2
# Skipping line 772: expected 1 fields, saw 2
# Skipping line 774: expected 1 fields, saw 2
# Skipping line 776: expected 1 fields, saw 2
# Skipping line 778: expected 1 fields, saw 2
# Skipping line 780: expected 1 fields, saw 2
# Skipping line 782: expected 1 fields, saw 2
# Skipping line 784: expected 1 fields, saw 2
# Skipping line 786: expected 1 fields, saw 2
# Skipping line 788: expected 1 fields, saw 2
# Skipping line 790: expected 1 fields, saw 2
# Skipping line 792: expected 1 fields, saw 2
# Skipping line 794: expected 1 fields, saw 2
# Skipping line 796: expected 1 fields, saw 2
# Skipping line 798: expected 1 fields, saw 2
# Skipping line 800: expected 1 fields, saw 2
# Skipping line 802: expected 1 fields, saw 2
# Skipping line 804: expected 1 fields, saw 2
# Skipping line 806: expected 1 fields, saw 2
# Skipping line 808: expected 1 fields, saw 2
# Skipping line 810: expected 1 fields, saw 2
# Skipping line 812: expected 1 fields, saw 2
# Skipping line 814: expected 1 fields, saw 2
# Skipping line 816: expected 1 fields, saw 2
# Skipping line 818: expected 1 fields, saw 2
# Skipping line 820: expected 1 fields, saw 2
# Skipping line 822: expected 1 fields, saw 2
# Skipping line 824: expected 1 fields, saw 2
# Skipping line 826: expected 1 fields, saw 2
# Skipping line 828: expected 1 fields, saw 2
# Skipping line 830: expected 1 fields, saw 2
# Skipping line 832: expected 1 fields, saw 2
# Skipping line 834: expected 1 fields, saw 2
# Skipping line 836: expected 1 fields, saw 2
# Skipping line 838: expected 1 fields, saw 2
# Skipping line 840: expected 1 fields, saw 2
# Skipping line 842: expected 1 fields, saw 2
# Skipping line 844: expected 1 fields, saw 2
# Skipping line 846: expected 1 fields, saw 2
# Skipping line 848: expected 1 fields, saw 2
# Skipping line 850: expected 1 fields, saw 2
# Skipping line 852: expected 1 fields, saw 2
# Skipping line 854: expected 1 fields, saw 2
# Skipping line 856: expected 1 fields, saw 2
# Skipping line 858: expected 1 fields, saw 2
# Skipping line 860: expected 1 fields, saw 2
# Skipping line 862: expected 1 fields, saw 2
# Skipping line 864: expected 1 fields, saw 2
# Skipping line 866: expected 1 fields, saw 2
# Skipping line 868: expected 1 fields, saw 2
# Skipping line 870: expected 1 fields, saw 2
# Skipping line 872: expected 1 fields, saw 2
# Skipping line 874: expected 1 fields, saw 2
# Skipping line 876: expected 1 fields, saw 2
# Skipping line 878: expected 1 fields, saw 2
# Skipping line 880: expected 1 fields, saw 2
# Skipping line 882: expected 1 fields, saw 2
# Skipping line 884: expected 1 fields, saw 2
# Skipping line 886: expected 1 fields, saw 2
# Skipping line 888: expected 1 fields, saw 2
# Skipping line 890: expected 1 fields, saw 2
# Skipping line 892: expected 1 fields, saw 2
# Skipping line 894: expected 1 fields, saw 2
# Skipping line 896: expected 1 fields, saw 2
# Skipping line 898: expected 1 fields, saw 2
# Skipping line 900: expected 1 fields, saw 2
# Skipping line 902: expected 1 fields, saw 2
# Skipping line 904: expected 1 fields, saw 2
# Skipping line 906: expected 1 fields, saw 2
# Skipping line 908: expected 1 fields, saw 2
# Skipping line 910: expected 1 fields, saw 2
# Skipping line 912: expected 1 fields, saw 2
# Skipping line 914: expected 1 fields, saw 2
# Skipping line 916: expected 1 fields, saw 2
# Skipping line 918: expected 1 fields, saw 2
# Skipping line 920: expected 1 fields, saw 2
# Skipping line 922: expected 1 fields, saw 2
# Skipping line 924: expected 1 fields, saw 2
# Skipping line 926: expected 1 fields, saw 2
# Skipping line 928: expected 1 fields, saw 2
# Skipping line 930: expected 1 fields, saw 2
# Skipping line 932: expected 1 fields, saw 2
# Skipping line 934: expected 1 fields, saw 2
# Skipping line 936: expected 1 fields, saw 2
# Skipping line 938: expected 1 fields, saw 2
# Skipping line 940: expected 1 fields, saw 2
# Skipping line 942: expected 1 fields, saw 2
# Skipping line 944: expected 1 fields, saw 2
# Skipping line 946: expected 1 fields, saw 2
# Skipping line 948: expected 1 fields, saw 2
# Skipping line 950: expected 1 fields, saw 2
# Skipping line 952: expected 1 fields, saw 2
# Skipping line 954: expected 1 fields, saw 2
# Skipping line 956: expected 1 fields, saw 2
# Skipping line 958: expected 1 fields, saw 2
# Skipping line 960: expected 1 fields, saw 2
# Skipping line 962: expected 1 fields, saw 2
# Skipping line 964: expected 1 fields, saw 2
# Skipping line 966: expected 1 fields, saw 2
# Skipping line 968: expected 1 fields, saw 2
# Skipping line 970: expected 1 fields, saw 2
# Skipping line 972: expected 1 fields, saw 2
# Skipping line 974: expected 1 fields, saw 2
# Skipping line 976: expected 1 fields, saw 2
# Skipping line 978: expected 1 fields, saw 2
# Skipping line 980: expected 1 fields, saw 2
# Skipping line 982: expected 1 fields, saw 2
# Skipping line 984: expected 1 fields, saw 2
# Skipping line 986: expected 1 fields, saw 2
# Skipping line 988: expected 1 fields, saw 2
# Skipping line 990: expected 1 fields, saw 2
# Skipping line 992: expected 1 fields, saw 2
# Skipping line 994: expected 1 fields, saw 2
# Skipping line 996: expected 1 fields, saw 2
# Skipping line 998: expected 1 fields, saw 2
# Skipping line 1000: expected 1 fields, saw 2
# Skipping line 1002: expected 1 fields, saw 2
# Skipping line 1004: expected 1 fields, saw 2
# Skipping line 1006: expected 1 fields, saw 2
# Skipping line 1008: expected 1 fields, saw 2
# Skipping line 1010: expected 1 fields, saw 2
# Skipping line 1012: expected 1 fields, saw 2
# Skipping line 1014: expected 1 fields, saw 2
# Skipping line 1016: expected 1 fields, saw 2
# Skipping line 1018: expected 1 fields, saw 2
# Skipping line 1020: expected 1 fields, saw 2
# Skipping line 1022: expected 1 fields, saw 2
# Skipping line 1024: expected 1 fields, saw 2
# Skipping line 1026: expected 1 fields, saw 2
# Skipping line 1028: expected 1 fields, saw 2
# Skipping line 1030: expected 1 fields, saw 2
# Skipping line 1032: expected 1 fields, saw 2
# Skipping line 1034: expected 1 fields, saw 2
# Skipping line 1036: expected 1 fields, saw 2
# Skipping line 1038: expected 1 fields, saw 2
# Skipping line 1040: expected 1 fields, saw 2
# Skipping line 1042: expected 1 fields, saw 2
# Skipping line 1044: expected 1 fields, saw 2
# Skipping line 1046: expected 1 fields, saw 2
# Skipping line 1048: expected 1 fields, saw 2
# Skipping line 1050: expected 1 fields, saw 2
# Skipping line 1052: expected 1 fields, saw 2
# Skipping line 1054: expected 1 fields, saw 2
# Skipping line 1056: expected 1 fields, saw 2
# Skipping line 1058: expected 1 fields, saw 2
# Skipping line 1060: expected 1 fields, saw 2
# Skipping line 1062: expected 1 fields, saw 2
# Skipping line 1064: expected 1 fields, saw 2
# Skipping line 1066: expected 1 fields, saw 2
# Skipping line 1068: expected 1 fields, saw 2
# Skipping line 1070: expected 1 fields, saw 2
# Skipping line 1072: expected 1 fields, saw 2
# Skipping line 1074: expected 1 fields, saw 2
# Skipping line 1076: expected 1 fields, saw 2
# Skipping line 1078: expected 1 fields, saw 2
# Skipping line 1080: expected 1 fields, saw 2
# Skipping line 1082: expected 1 fields, saw 2
# Skipping line 1084: expected 1 fields, saw 2
# Skipping line 1086: expected 1 fields, saw 2
# Skipping line 1088: expected 1 fields, saw 2
# Skipping line 1090: expected 1 fields, saw 2
# Skipping line 1092: expected 1 fields, saw 2
# Skipping line 1094: expected 1 fields, saw 2
# Skipping line 1096: expected 1 fields, saw 2
# Skipping line 1098: expected 1 fields, saw 2
# Skipping line 1100: expected 1 fields, saw 2
# Skipping line 1102: expected 1 fields, saw 2
# Skipping line 1104: expected 1 fields, saw 2
# Skipping line 1106: expected 1 fields, saw 2
# Skipping line 1108: expected 1 fields, saw 2
# Skipping line 1110: expected 1 fields, saw 2
# Skipping line 1112: expected 1 fields, saw 2
# Skipping line 1114: expected 1 fields, saw 2
# Skipping line 1116: expected 1 fields, saw 2
# Skipping line 1118: expected 1 fields, saw 2
# Skipping line 1120: expected 1 fields, saw 2
# Skipping line 1122: expected 1 fields, saw 2
# Skipping line 1124: expected 1 fields, saw 2
# Skipping line 1126: expected 1 fields, saw 2
# Skipping line 1128: expected 1 fields, saw 2
# Skipping line 1130: expected 1 fields, saw 2
# Skipping line 1132: expected 1 fields, saw 2
# Skipping line 1134: expected 1 fields, saw 2
# Skipping line 1136: expected 1 fields, saw 2
# Skipping line 1138: expected 1 fields, saw 2
# Skipping line 1140: expected 1 fields, saw 2
# Skipping line 1142: expected 1 fields, saw 2
# Skipping line 1144: expected 1 fields, saw 2
# Skipping line 1146: expected 1 fields, saw 2
# Skipping line 1148: expected 1 fields, saw 2
# Skipping line 1150: expected 1 fields, saw 2
# Skipping line 1152: expected 1 fields, saw 2
# Skipping line 1154: expected 1 fields, saw 2
# Skipping line 1156: expected 1 fields, saw 2
# Skipping line 1158: expected 1 fields, saw 2
# Skipping line 1160: expected 1 fields, saw 2
# Skipping line 1162: expected 1 fields, saw 2
# Skipping line 1164: expected 1 fields, saw 2
# Skipping line 1166: expected 1 fields, saw 2
# Skipping line 1168: expected 1 fields, saw 2
# Skipping line 1170: expected 1 fields, saw 2
# Skipping line 1172: expected 1 fields, saw 2
# Skipping line 1174: expected 1 fields, saw 2
# Skipping line 1176: expected 1 fields, saw 2
# Skipping line 1178: expected 1 fields, saw 2
# Skipping line 1180: expected 1 fields, saw 2
# Skipping line 1182: expected 1 fields, saw 2
# Skipping line 1184: expected 1 fields, saw 2
# Skipping line 1186: expected 1 fields, saw 2
# Skipping line 1188: expected 1 fields, saw 2
# Skipping line 1190: expected 1 fields, saw 2
# Skipping line 1192: expected 1 fields, saw 2
# Skipping line 1194: expected 1 fields, saw 2
# Skipping line 1196: expected 1 fields, saw 2
# Skipping line 1198: expected 1 fields, saw 2
# Skipping line 1200: expected 1 fields, saw 2
# Skipping line 1202: expected 1 fields, saw 2
# Skipping line 1204: expected 1 fields, saw 2
# Skipping line 1206: expected 1 fields, saw 2
# Skipping line 1208: expected 1 fields, saw 2
# Skipping line 1210: expected 1 fields, saw 2
# Skipping line 1212: expected 1 fields, saw 2
# Skipping line 1214: expected 1 fields, saw 2
# Skipping line 1216: expected 1 fields, saw 2
# Skipping line 1218: expected 1 fields, saw 2
# Skipping line 1220: expected 1 fields, saw 2
# Skipping line 1222: expected 1 fields, saw 2
# Skipping line 1224: expected 1 fields, saw 2
# Skipping line 1226: expected 1 fields, saw 2
# Skipping line 1228: expected 1 fields, saw 2
# Skipping line 1230: expected 1 fields, saw 2
#
#   df = pd.read_csv(url, encoding='latin1', on_bad_lines='warn')
# Latin-1 failed: Error tokenizing data. C error: Buffer overflow caught - possible malformed input file.
#
# Read with Python engine and error replacement
# Note: Removed 90 corrupted rows during cleaning
#
# First 5 rows of successfully loaded data:
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 1: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 4: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 8: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 9: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 10: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 11: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 12: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 13: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# ...
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 82: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 90: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 91: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 94: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 95: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 97: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 100: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 103: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 104: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 106: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 107: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 109: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 110: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 112: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 115: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 118: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 123: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 124: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 125: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 126: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 130: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 131: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 132: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 133: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 135: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 137: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 138: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 146: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 149: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 152: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 154: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 155: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 157: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 158: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 159: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 160: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 162: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 163: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 165: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 169: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 171: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 172: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 175: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 180: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 182: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 183: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 189: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 192: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 193: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 194: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 195: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 197: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 198: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 200: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 202: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 203: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 204: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 208: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 212: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 213: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 214: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 215: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 216: new-line character seen in unquoted field - do you need to open the file with newline=''?
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 34: Expected 3 fields in line 34, saw 4
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 51: Expected 3 fields in line 51, saw 4
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 63: Expected 3 fields in line 63, saw 6
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 66: Expected 3 fields in line 66, saw 5
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 72: Expected 3 fields in line 72, saw 4
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 74: Expected 3 fields in line 74, saw 7
#
#   df = pd.read_csv(data, sep=',', engine='python',
# /tmp/ipython-input-3283461599.py:33: ParserWarning: Skipping line 75: Expected 3 fields in line 75, saw 4
#
#   df = pd.read_csv(data, sep=',', engine='python',
#                                                                                                       ¾âAió TbJãAãÏ]®}í"=(]±áG¯rý»ÏïÏw_%Æí%¯ÿO?üë?AõÅGyà¿
# OW(W¢ÿ÷Ë:>g|ºÿf<¥ÑÓèe6*¾ÿØ[Ú>*
# ^füß}í¿ÌxÌøáñOú·ãòx@¸è\te÷
# ±/Í_ÿûßÒ±ÿñ»/¿K... éÊ6g¼ª8þ¿}NñµÒbåÛbÅrÅ¢Sù=b¸j¡¯
# ýüxÚxh...               2T¢àQçÔé¡Úk$31VjóÉ·ìdèIAöÜÓ
# bÇIV{øä`·ýöÈ&WZO±UÈÑG
# wÉ                   Û_Ç_þ´\tµu2l¥oB¦qóäã¯ Ð:
# 2mA¦KA1
# cØoö...
# fãï
#
# w¨Ë5{^mÏil±89¨d:²}ö6Áºæ²HIlàë Â...
# ¾ýØo~Òú2Ó6µø5®È»q\tí)ü¢¤ÆWÕ
# b`·¡
# 9MúþñêÅ... În!ýÛ                                              !ÁÜ¼»Ò5ÖÈþ¶AW(âù
# ÆOwýìF;1þ9þN>;Pt\Ä?lìªÿªU...
# 9PiÛ¦ã(Ô·AJ^óÎè8d²1\t§á-bçà@ñóÃ¯ûë9<Ù... \tjJöÈB´ÝV²ðÿÇi!ÂEe¨ñ9pÇÞ#Q¶m1Ãñ9e7Ç ...                                 KH«Åc§ÈM0sxaà`ð
# y36Ìn
# öìVz/(7$ªã3                             ï PØ£&_-rÎT5épçÚ.
# Ó}áçÜTsUÚ´EÜàË¬¾...  b]¹:
# Ýw¥v©yÙIYdÐ#
# Ù7Õá<ªté¢l
# ...
# Dataset dimensions: (12, 1)
#
# Column types:
#  ¾âAió TbJãAãÏ]®}í"=(]±áG¯rý»ÏïÏw_%Æí%¯ÿO?üë?AõÅGyà¿OW(W¢ÿ÷Ë:>g|ºÿf<¥ÑÓèe6*¾ÿØ[Ú>*    object
# dtype: object

# %%
### 1.2 Data Cleaning
# Handle missing values
print("Missing values before cleaning:")
print(df.isnull().sum())

# Impute missing values
# For numerical columns, use median (robust to outliers)
for col in numerical_cols:
    df[col].fillna(df[col].median(), inplace=True)

# For categorical columns, use mode
for col in categorical_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)

# Handle outliers
# Cap income at 99th percentile
income_99th = df['Income'].quantile(0.99)
df['Income'] = np.where(df['Income'] > income_99th, income_99th, df['Income'])

# Remove unrealistic birth years (before 1920)
df = df[df['Year_Birth'] >= 1920]

# Convert date columns
df['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'])

# Validate cleaning
print("\nMissing values after cleaning:")
print(df.isnull().sum())

print("\nDataset dimensions after cleaning:", df.shape)
# Out:
# Missing values before cleaning:
# ¾âAió TbJãAãÏ]®}í"=(]±áG¯rý»ÏïÏw_%Æí%¯ÿO?üë?AõÅGyà¿OW(W¢ÿ÷Ë:>g|ºÿf<¥ÑÓèe6*¾ÿØ[Ú>*    0
# dtype: int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1491920413.py in <cell line: 0>()
#       6 # Impute missing values
#       7 # For numerical columns, use median (robust to outliers)
# ----> 8 for col in numerical_cols:
#       9     df[col].fillna(df[col].median(), inplace=True)
#      10
#
# NameError: name 'numerical_cols' is not defined

# %%
### 1.3 Feature Engineering

# Create Total Spend Amount
spending_cols = ['MntWines', 'MntFruits', 'MntMeatProducts',
                 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']
df['TotalSpend'] = df[spending_cols].sum(axis=1)

# Create CustomerValueTier
conditions = [
    (df['TotalSpend'] >= 1000),
    (df['TotalSpend'] >= 500) & (df['TotalSpend'] < 1000),
    (df['TotalSpend'] >= 200) & (df['TotalSpend'] < 500),
    (df['TotalSpend'] < 200)
]
tiers = ['Premium', 'Gold', 'Silver', 'Bronze']
df['CustomerValueTier'] = np.select(conditions, tiers)

# Create CustomerAge
current_year = datetime.now().year
df['CustomerAge'] = current_year - df['Year_Birth']

# Create AverageSpending
df['AverageSpending'] = df[spending_cols].mean(axis=1)

# Display new features
print("New features created:")
display(df[['TotalSpend', 'CustomerValueTier', 'CustomerAge', 'AverageSpending']].head())

# %%
## Part 2: Exploratory Data Analysis

# %%
### 2.1 Univariate Analysis
# Set up plots
plt.figure(figsize=(15, 10))

# Total Spend Amount
plt.subplot(2, 2, 1)
sns.histplot(df['TotalSpend'], kde=True, bins=30)
plt.title('Distribution of Total Spend Amount')
plt.xlabel('Total Spend ($)')
mean_spend = df['TotalSpend'].mean()
plt.axvline(mean_spend, color='r', linestyle='--')
plt.text(mean_spend*1.1, 100, f'Mean: ${mean_spend:.2f}', color='r')

# Customer Age
plt.subplot(2, 2, 2)
sns.histplot(df['CustomerAge'], kde=True, bins=30)
plt.title('Distribution of Customer Age')
plt.xlabel('Age (years)')
mean_age = df['CustomerAge'].mean()
plt.axvline(mean_age, color='r', linestyle='--')
plt.text(mean_age*1.1, 100, f'Mean: {mean_age:.1f} years', color='r')

# Recency
plt.subplot(2, 2, 3)
sns.histplot(df['Recency'], kde=True, bins=30)
plt.title('Distribution of Recency (Days Since Last Purchase)')
plt.xlabel('Days')
mean_recency = df['Recency'].mean()
plt.axvline(mean_recency, color='r', linestyle='--')
plt.text(mean_recency*1.1, 100, f'Mean: {mean_recency:.1f} days', color='r')

# Web Visits per Month
plt.subplot(2, 2, 4)
sns.histplot(df['NumWebVisitsMonth'], kde=True, bins=15)
plt.title('Distribution of Web Visits per Month')
plt.xlabel('Visits')
mean_visits = df['NumWebVisitsMonth'].mean()
plt.axvline(mean_visits, color='r', linestyle='--')
plt.text(mean_visits*1.1, 150, f'Mean: {mean_visits:.1f} visits', color='r')

plt.tight_layout()
plt.show()

# %%
### 2.2 Bivariate and Multivariate Analysis

# Correlation matrix heatmap
plt.figure(figsize=(12, 8))
corr_matrix = df[numerical_cols].corr()
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm',
            annot_kws={'size': 8}, vmin=-1, vmax=1)
plt.title('Correlation Matrix of Numerical Variables')
plt.show()

# Strongest correlations
print("Top 5 positive correlations:")
print(corr_matrix.unstack().sort_values(ascending=False).drop_duplicates().head(6))

print("\nTop 5 negative correlations:")
print(corr_matrix.unstack().sort_values().drop_duplicates().head(5))

# Regression plot: Total Spend vs Customer Age
plt.figure(figsize=(8, 6))
sns.regplot(x='CustomerAge', y='TotalSpend', data=df,
            scatter_kws={'alpha':0.3}, line_kws={'color':'red'})
plt.title('Total Spend Amount vs Customer Age')
plt.show()

# Marital Status vs Spending patterns
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
df.groupby('Marital_Status')['MntWines'].mean().sort_values().plot(kind='bar')
plt.title('Average Wine Spending by Marital Status')
plt.ylabel('Average Spend ($)')

plt.subplot(1, 3, 2)
df.groupby('Marital_Status')['MntFruits'].mean().sort_values().plot(kind='bar')
plt.title('Average Fruit Spending by Marital Status')

plt.subplot(1, 3, 3)
df.groupby('Marital_Status')['MntMeatProducts'].mean().sort_values().plot(kind='bar')
plt.title('Average Meat Spending by Marital Status')

plt.tight_layout()
plt.show()

# %%
## Part 3: Model Development & Deployment

# %%
### 3.1 Data Preprocessing

# Feature selection
# Important features based on EDA:
categorical_features = ['Education', 'Marital_Status']
numerical_features = ['CustomerAge', 'Income', 'Recency',
                     'NumWebVisitsMonth', 'NumDealsPurchases']

# One-hot encoding
df_encoded = pd.get_dummies(df, columns=categorical_features, drop_first=True)

# Standard scaling
scaler = StandardScaler()
df_encoded[numerical_features] = scaler.fit_transform(df_encoded[numerical_features])

# Train-test split
X = df_encoded[numerical_features +
              [col for col in df_encoded.columns if col.startswith('Education_') or col.startswith('Marital_Status_')]]
y_reg = df_encoded['TotalSpend']
y_clf = df_encoded['CustomerValueTier']

X_train, X_test, y_reg_train, y_reg_test, y_clf_train, y_clf_test = train_test_split(
    X, y_reg, y_clf, test_size=0.2, random_state=42)

print(f"Training set shape: {X_train.shape}")
print(f"Test set shape: {X_test.shape}")

# %%
### 3.2 Model Development

# Regression model
reg_model = LinearRegression()
reg_model.fit(X_train, y_reg_train)
y_reg_pred = reg_model.predict(X_test)

# Regression evaluation
rmse = np.sqrt(mean_squared_error(y_reg_test, y_reg_pred))
r2 = r2_score(y_reg_test, y_reg_pred)

print("Regression Model Performance:")
print(f"RMSE: {rmse:.2f}")
print(f"R2 Score: {r2:.2f}")

# Classification model
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5]
}

clf = RandomForestClassifier(random_state=42)
grid_search = GridSearchCV(clf, param_grid, cv=5, scoring='f1_weighted')
grid_search.fit(X_train, y_clf_train)

best_clf = grid_search.best_estimator_
y_clf_pred = best_clf.predict(X_test)

print("\nClassification Model Performance:")
print("Best Parameters:", grid_search.best_params_)
print("\nClassification Report:")
print(classification_report(y_clf_test, y_clf_pred))

print("\nConfusion Matrix:")
print(confusion_matrix(y_clf_test, y_clf_pred))

# Model comparison
print("\nModel Comparison:")
print("Regression (Total Spend Prediction):")
print(f"- RMSE: {rmse:.2f}, R2: {r2:.2f}")
print("\nClassification (Customer Value Tier Prediction):")
print("- Best for customer segmentation and targeted marketing")
print("- Provides clear business rules for customer tiers")

# %%
### 3.4 Model Packaging and Deployment

# Package the best model (classification)
model_package = {
    'model': best_clf,
    'scaler': scaler,
    'features': numerical_features + categorical_features
}

with open('ecommerce_model.pkl', 'wb') as f:
    pickle.dump(model_package, f)

# Load and test the model
with open('ecommerce_model.pkl', 'rb') as f:
    loaded_package = pickle.load(f)

sample_data = pd.DataFrame({
    'CustomerAge': [50],
    'Income': [60000],
    'Recency': [30],
    'NumWebVisitsMonth': [5],
    'NumDealsPurchases': [2],
    'Education': ['Graduation'],
    'Marital_Status': ['Married']
})

# Preprocess sample data
sample_encoded = pd.get_dummies(sample_data,
                              columns=categorical_features,
                              drop_first=True)

# Ensure all expected columns are present
for col in loaded_package['features']:
    if col not in sample_encoded.columns and col in numerical_features:
        sample_encoded[col] = 0  # Add missing numerical columns
    elif col not in sample_encoded.columns and (col.startswith('Education_') or col.startswith('Marital_Status_')):
        sample_encoded[col] = 0  # Add missing one-hot columns

# Scale numerical features
sample_encoded[numerical_features] = loaded_package['scaler'].transform(
    sample_encoded[numerical_features])

# Predict
prediction = loaded_package['model'].predict(sample_encoded)
print(f"\nPredicted Customer Value Tier: {prediction[0]}")

# Deployment recommendations
print("\nDeployment Recommendations:")
print("1. Deploy as a REST API for integration with CRM systems")
print("2. Create batch prediction service for customer segmentation")
print("3. Implement real-time scoring for website personalization")
print("4. Package with monitoring for model performance tracking")
print("5. Document API specifications for developer consumption")
